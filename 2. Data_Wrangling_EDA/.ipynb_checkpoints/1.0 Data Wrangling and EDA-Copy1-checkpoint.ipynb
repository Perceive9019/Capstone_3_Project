# %% [markdown]
# # UK Electricity Consumption Forecast - Time Series Analysis

# %% [markdown]
# The general framework we will use to carryout the time series forecasting analysis is as follows:
#
# ### 1. **Understanding the Dataset**
# - Load our dataset into a dataset.
# - Visualize the data to understand its pattern (e.g., using Matplotlib or Seaborn in Python). - Look for seasonality, trends, and potential outliers.
# - Check for missing data and decide how we want to handle them (e.g., interpolation, forward-fill, or dropping).
#
# ### 2. **Decomposition of the Series**
# Using the package `statsmodels.tsa.seasonal` in Python, we will decompose our time series into:
# - Trend component
# - Seasonal component
# - Residual component
#
# This gives us insights into the nature of the patterns in our data.
#
# ### 3. **Stationarity**
# Most time series forecasting methods assume that the underlying time series is stationary, which means statistical properties like mean, variance, etc., are constant over time.
#
# - Test for stationarity using the Dickey-Fuller test (`adfuller` function from `statsmodels.tsa.stattools`) and Kwiatkowski-Phillips-Schmidt-Shin test (`KPSS`function from `statsmodels.tsa.stattools`).
# - If the series is non-stationary, we can make it stationary by differencing or taking the log, etc.
#
# ### 4. **Selecting a Model**
# Bewlo are the models we will use to forecast electricity demand in the UK:
#
# - **ARIMA** (AutoRegressive Integrated Moving Average): A popular model for time series forecasting. We'll need to find optimal parameters (p,d,q) for the model. We can use tools like `auto_arima` in the `pmdarima` library to find the best parameters.
#
# - **Prophet**: Developed by Facebook, it's useful for datasets with strong seasonal patterns and multiple seasonality.
#
# ### 5. **Training and Validation**
# - Split the dataset into a training set and a validation (or test) set. The training set will be used to train the model, while the validation set will be used to test its performance.
# - Fit the selected model to the training data.
# - Forecast for the validation period and compare the forecasted values with the actual values.
#
# ### 6. **Model Evaluation**
# Use metrics like Mean Absolute Percentage Error (MAPE), Root Mean Squared Error (RMSE), or Mean Absolute Error (MAE) to measure the accuracy of our forecasts.
#
# ### 7. **Forecasting**
# Once satisfied with the model's performance on the validation set, we can use the entire dataset to train the model and then forecast future consumption or demand.
#
# ### 8. **Post-processing**
# Some models might give forecasts that need post-processing. For example, if we log-transformed our data, we'll need to reverse the transformation on our forecasts.

# %% [markdown]
# ## 1. Understanding the Dataset

# %% [markdown]
# ### 1a. Load relevant libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from statsmodels.tsa.seasonal import seasonal_decompose  # Decomposition
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1b. Load the data

# %%
data_path = '/Users/elevate/Documents/Springboard Data Science/GitHub Repos/Capstone_3_Project/1. Data Source/historic_demand_2009_2023_noNaN.csv'
data = pd.read_csv(data_path)

# %%
#

# %% [markdown]
# ## 1c. Visualize the data

# %%
# Convert the 'settlement_date' column to a datetime format 
data['settlement_date'] = pd.to_datetime(data['settlement_date'])

# %%
# VIsualise the data
plt.figure(figsize=(15, 7)) # set the figure for the plot

# Plotting the 'settlement_date' on the x-axis and 'tsd' on the y-axis
plt.plot(data['settlement_date'], data['tsd'], label='TSD', color = 'blue')
plt.title('Time Series of TSD Over Time')
plt.xlabel('Date')
plt.ylabel('TSD Measured in MW')
plt.grid(True) # Add gird for better readability
plt.legend()
plt.show()

# %% [markdown]
# ### 1d. Check for missing data

# %%
print(data.isnull().sum())
# Out:
# settlement_date              0
# settlement_period            0
# period_hour                  0
# nd                           0
# tsd                          0
# england_wales_demand         0
# embedded_wind_generation     0
# embedded_wind_capacity       0
# embedded_solar_generation    0
# embedded_solar_capacity      0
# non_bm_stor                  0
# pump_storage_pumping         0
# ifa_flow                     0
# ifa2_flow                    0
# britned_flow                 0
# moyle_flow                   0
# east_west_flow               0
# nemo_flow                    0
# is_holiday                   0
# dtype: int64

# %% [markdown]
# ## 2. Decomposition of the Series
# Given that we suspect seasonality in the data, due to the changing amplitude over time, decomposing the series into its trend, seasonal, and residual components can help validate this suspicion and provide deeper insights.

# %%
# Upload jpg file into Jupyter notebook
from IPython.display import Image
Image(filename='Additive or multiplicative?.jpg')

# %% [markdown]
# We will compare models to determine which one provides a better fit.
#
# **Additive Model**: The additive model is used when the seasonal variation is roughly constant throughout the series. In other words, the difference in amplitude between peaks and troughs remains approximately the same over time.
#
# **Multiplicative Model**: The multiplicative model is appropriate when the seasonal variation increases or decreases as the time series data grows. In other words, as the data values increase, the difference between peaks and troughs becomes proportionally wider.

# %% [markdown]
# **Note**:
# Since the data is collected every 30 minutes with 48 entries per day, and you're trying to capture daily seasonality, then the frequency should be set to 48 (since there are 48 data points in a single day).
#
# However, if you're trying to capture another form of seasonality, such as weekly or yearly, you would adjust accordingly:
#
# For weekly seasonality: 48 x 7 = 336
#
# For yearly seasonality (assuming no leap year): 48 x 365 = 17,520
#
# Given our data's granularity, it's common to first look at daily patterns, especially for data that is recorded at 30-minute intervals, as intraday variations might be of primary interest.
#
# Thus, to capture daily seasonality, set freq=48 when decomposing.

# %% [markdown]
# ### 2.1 Decompose the series

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Decompose the tsd series
decomposition = seasonal_decompose(data['tsd'], model='additive', period=48)

# Plot the decomposed components
plt.figure(figsize=(15,10))

plt.subplot(4,1,1) # 4 rows, 1 column plot 1
plt.plot(data['settlement_date'], data['tsd'], label='Original')
plt.legend(loc='upper left')
plt.title('Original TSD Series')

plt.subplot(4,1,2)
plt.plot(data['settlement_date'], decomposition.trend, label='Trend', color='blue' )
plt.legend(loc='upper left')
plt.title('TSD Trend')

plt.subplot(4,1,3)
plt.plot(data['settlement_date'], decomposition.seasonal, label='Seasonal', color='green')
plt.legend(loc='upper left')
plt.title('TSD Seasonal')

plt.subplot(4,1,4)
plt.plot(data['settlement_date'], decomposition.resid, label='Residual', color='red')
plt.legend(loc='upper left')
plt.title('TSD Residual')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Why is the Seasonal Plot a solid green reactangle?

# %% [markdown]
# If the seasonal plot displays as a solid green rectangle, it typically indicates that the amplitude of the seasonal component is so large in comparison to the other plotted values that it essentially dwarfs them, making the plot look like a solid block.
#
# There are a few possible reasons and solutions for this:
#
# - **Scale Differences**: The seasonal variations might be very large compared to the trend and residual components. This could cause the seasonal plot to appear as a solid block when plotted on the same scale as the other components. In such cases, you can plot the seasonal component on a different scale.
#
# - **High Frequency**: If you're capturing daily seasonality with period=48 and have several years of data, the result will be a very high-frequency seasonal pattern. When plotted over several years, this can appear as a solid block because the fluctuations happen so frequently that they're hard to distinguish at the scale of the entire dataset.
#
# - **Decomposition Model**: As previously discussed, you might be using the wrong decomposition model (additive vs. multiplicative). If the seasonal pattern is better described by a multiplicative model but you're using an additive model, the seasonal decomposition might not be accurate.

# %%
# Decompose the tsd series
decomposition = seasonal_decompose(data['tsd'], model='multiplicative', period=48)

# Plot the decomposed components
plt.figure(figsize=(15,10))

plt.subplot(4,1,1) # 4 rows, 1 column plot 1
plt.plot(data['settlement_date'], data['tsd'], label='Original')
plt.legend(loc='upper left')
plt.title('Original TSD Series')

plt.subplot(4,1,2)
plt.plot(data['settlement_date'], decomposition.trend, label='Trend', color='blue' )
plt.legend(loc='upper left')
plt.title('TSD Trend')

plt.subplot(4,1,3)
plt.plot(data['settlement_date'], decomposition.seasonal, label='Seasonal', color='green')
plt.legend(loc='upper left')
plt.title('TSD Seasonal')

plt.subplot(4,1,4)
plt.plot(data['settlement_date'], decomposition.resid, label='Residual', color='red')
plt.legend(loc='upper left')
plt.title('TSD Residual')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Note**:
# The multiplicative model also shows the seasonal plot as a solid green plot.
# We are going to try plotting the seasonal component separately to visualize daily seasonality over a shorter timeframe (e.e. one month)

# %%
# Timeframe January 1, 2021 to February 1, 2021
subset_data = data[(data['settlement_date'] >= '2021-01-01') & (data['settlement_date'] < '2021-02-01')]

# Extract the corresponding seasonal values from the decomposition
subset_seasonal = decomposition.seasonal[subset_data.index]

# Plot the seasonal component for this subset
plt.figure(figsize=(15,7))
plt.plot(subset_data['settlement_date'], subset_seasonal, color='green')
plt.title('Seasonal Component for January 2021')
plt.xlabel('Date')
plt.ylabel('Seasonal Value')
plt.grid(True)
plt.xticks(rotation=45)  # rotate the x-axis labels for better visibility
plt.tight_layout()
plt.show()

# %% [markdown]
# If the seasonal component displays tall, consistent amplitudes that are the same in height and width for the entire month, this suggests a very strong, regular daily seasonality in your data. Specifically:
#
# **Strong Daily Seasonality**: The presence of amplitudes implies that there's a repeating pattern in your data every day. This could be due to daily routines, operations, or any other factors that drive the consumption or demand in your dataset.
#
# **Consistency in Seasonal Patterns**: The fact that these amplitudes are the same in height and width suggests that this daily seasonality is very consistent throughout the month. This means that whatever is causing this daily pattern happens with similar intensity and duration every day.
#
# For example, if you're analyzing electricity consumption, a consistent daily pattern might arise from behaviors like people waking up, using appliances in the morning, having a lull during the day, peaking in the evening when everyone's home, and then dropping off during the night. This cycle would repeat every day.
#
# Such patterns are essential to recognize in time series forecasting because they help inform the type of models you might use and the features you might want to incorporate. Given this daily seasonality, models like SARIMA, which can account for seasonality, would be particularly appropriate for forecasting this data.
#
# Remember, however, that the seasonality component only shows the repeating patterns in the data, stripped of any long-term trend or irregularities. The original data series will have this seasonal pattern superimposed with other components (like trends or residuals). It's the combination of all these components that gives the original series its unique characteristics.

# %% [markdown]
# ### Save Data Wrangling and EDA Notebook

# %%
data.to_parquet('data')

# %% [markdown]
# ## 3. Testing for Stationarity
# Before you can apply most time series forecasting methods, you need to ensure that your time series is stationary. Stationarity means that the statistical properties of the series, like mean, variance, and autocorrelation, are constant over time.

# %% [markdown]
# ### 3.1 ADF Test:
# The Augmented Dickey-Fuller test is a formal statistical test for stationarity. The null hypothesis of the test is that the time series can be represented by a unit root, which is not stationary (has some time-dependent structure). The alternative hypothesis is that the time series is stationary.

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(data['tsd'])

# Pring test-statistic
print('ADF Statistic: %f' % result[0])

#Print p-value
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -16.920976
# p-value: 0.000000

# %% [markdown]
# The Augmented Dickey-Fuller (ADF) test results indicate the following:
#
#  - ADF Statistic: A value of -16.920976 is highly negative.
#  - p-value: A value of 0.000000 (essentially 0) is far below the common significance level (like 0.05).
#
# **Interpretation**:
#
# Given these results, you would reject the null hypothesis of the ADF test, suggesting that the time series does not have a unit root and is stationary.
#
#     - Remember:
#     - Null Hypothesis (H0): The time series has a unit root (i.e., it's non-stationary).
#     - Alternative Hypothesis (H1): The time series does not have a unit root (i.e., it's stationary).
#
# This is a good indication, especially if we're looking to model oour time series with methods like ARIMA or SARIMA. A stationary series often leads to better model performance because the statistical properties (mean, variance, autocorrelation) of the series remain constant over time, which is an assumption in many time series forecasting methods.
#
# Given that our data appears to be stationary, we can proceed to the next steps of modeling, which involve selecting an appropriate time series forecasting model and training it on your data.

# %% [markdown]
# ### 3.2 Testing for stationarity with KPSS
# Checking for stationarity using both the ADF and KPSS tests provides a more comprehensive view of the data's stationarity.

# %% [markdown]
# **KPSS Test** :
# - Null Hypothesis (H0): The time series is stationary around a deterministic trend.
# - Alternative Hypothesis (H1): The time series is not stationary (has a unit root).
#
#      - If the p-value is less than a threshold (e.g., 0.05), then you reject the null hypothesis, suggesting the time series is non-stationary.
#     - If the p-value is greater than the threshold, you fail to reject the null hypothesis and infer that the time series is stationary.

# %%
from statsmodels.tsa.stattools import kpss

# Perform the KPSS test
kpss_result = kpss(data['tsd'])

# Print the test-statistic
print('KPSS Statistic: %f' % kpss_result[0])

# Print the p-value
print('p-value: %f' % kpss_result[1])

# Print Critical Values
print('Critical Values:', kpss_result[3])
# Out:
# KPSS Statistic: 41.546408
# p-value: 0.010000
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}

# %% [markdown]
# **Note**:
# For the KPSS test, the critical values determine the thresholds at which you can reject the null hypothesis. The KPSS test generally provides critical values for various significance levels (e.g., 1%, 5%, 10%).
#
# If the KPSS statistic is greater than the critical value at a certain significance level, then you can reject the null hypothesis at that significance level.

# %% [markdown]
# The KPSS test results indicate the following:
#
# - **KPSS Statistic**: A value of 41.546408 is significantly larger than any of the provided critical values.
# - **p-value**: A value of 0.010000 (or 1%) is below the common significance levels (like 0.05 or 0.01).
#
# **Interpretation**:
#
# Given these results:
#
# 1. The KPSS statistic of 41.546408 is well above all the critical values, including the 1% level.
# 2. The p-value of 0.010000 suggests that you reject the null hypothesis at a 1% significance level.
#
# This means that according to the KPSS test, we would reject the null hypothesis, suggesting that the time series **is not stationary around a deterministic trend**.
#
# However, remember that the ADF test indicated that the series was stationary. This discrepancy between the ADF and KPSS tests suggests that the series might be **difference-stationary**. In other words, differencing the series once might make it stationary.
#
# In practice, when you get conflicting results from ADF and KPSS:
#
# - ADF indicates stationary, and KPSS indicates non-stationary: The series might be difference-stationary. Differencing can make the series stationary, and you might consider using techniques like ARIMA that involve integrated (I) components.
#
# Given the results, the next logical step could be to difference the series once and then re-run both the ADF and KPSS tests on the differenced data to see if it becomes stationary. Alternatively, you could proceed with models that can handle and account for non-stationarity, like SARIMA or Prophet.

# %% [markdown]
# **Note**:
# Difference-stationary means that the 'tsd' series becomes stationary after differencing it a certain number of times. The most common approach is to take the first difference, but sometimes a second or even third difference might be necessary.

# %% [markdown]
# ### 3.3 Compute Difference-Stationary

# %%
# Create a new column called tsd_diff
data['tsd_diff'] = data['tsd'].diff().dropna() # drop missing values

# %% [markdown]
# ### 3.4 Visualize the difference data

# %%
plt.figure(figsize=(12, 6))
data['tsd_diff'].plot(title='First Difference of tsd')
plt.show()

# %% [markdown]
# ### 3.5 Re-run ADF and KPSS test on tsd_diff

# %%
adf_result_diff = adfuller(data['tsd_diff'].dropna())
print('ADF Statistic (Difference Data):', adf_result_diff[0])
print('p-value:', adf_result_diff[1])
# Out:
# ADF Statistic (Difference Data): -66.06649322169788
# p-value: 0.0

# %%
kpss_result_diff = kpss(data['tsd_diff'].dropna())
print('KPSS Statistic (Difference Data):', kpss_result_diff[0])
print('p-value:', kpss_result_diff[1])
print('Critical Values:', kpss_result_diff[3])
# Out:
# KPSS Statistic (Difference Data): 0.0007534262677409369
# p-value: 0.1
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}

# %% [markdown]
# Let's interpret these results:
#
# ##### ADF Test (on Differenced Data):
#
# - **ADF Statistic**: \(-66.06649322169788\) is highly negative.
# - **p-value**: 0.0 is essentially 0.
#
# **Interpretation**: The ADF test suggests that the differenced series is stationary, as the p-value is significantly less than the commonly used significance level (0.05).
#
# ##### KPSS Test (on Differenced Data):
#
# - **KPSS Statistic**: \(0.0007534262677409369\) is way below the critical values.
# - **p-value**: 0.1 is above the common significance levels.
#
# **Interpretation**: Given the p-value(<0.005) and the KPSS statistic being below the critical values, we fail to reject the null hypothesis. This suggests that the differenced series is stationary around a deterministic trend.
#
# In conclusion, both tests agree that after taking the first difference, our time series data is stationary. This is good news for most time series forecasting techniques, as many of them require or at least perform better when the data is stationary.
#
# The next step involves choosing and fitting a forecasting model to the differenced (stationary) data, like ARIMA or SARIMA. We can also work on selecting the right order of differences, AR terms, and MA terms if you'd like to proceed with the ARIMA model.

# %% [markdown]
# ### Save EDA & Preprocessing DataFrame

# %%
data.to_parquet()

# %% [markdown]
# ## 4. Selecting a Model

# %% [markdown]
# Since our data has both a seasonal component and has been differenced to achieve stationarity, a Seasonal ARIMA (SARIMA) model would be a suitable choice. SARIMA allows for both non-seasonal (p, d, q) and seasonal (P, D, Q, S) components.

# %% [markdown]
# ### 4.1 Model Order Selection
# To determine the optimal Non-seasonal orders: (p, d, q) and Seasonal orders:(P, D, Q, S) parameters, we can utilize tools like the auto_arima function from the pmdarima library, which conducts a search over possible model orders and chooses the best.
#
# **Note**:
# - Non-seasonal orders
#      - p:autoregressive order
#      - d:differencing order
#      - q:moving averge order
#
# - Seasonal orders
#      - P:seasonal autoregressive order
#      - D:seasonal differencind order
#      - Q:seasonal moving averge order
#      - S: number of time steps per cycle

# %% [markdown]
# **Note:**
#
# We will use the pmdarima: This is a third-party library that provides the auto_arima function, among other utilities. auto_arima helps in determining the best ARIMA/SARIMA parameters (p, d, q, P, D, Q, S) by trying out a range of values and selecting the one with the lowest AIC (or other specified criteria). Essentially, it's a useful tool for hyperparameter tuning for ARIMA/SARIMA models.

# %%
from pmdarima import auto_arima

# Determine the SARIMA order for the differenced data
sarima_order = auto_arima(data['tsd_diff'].dropna(), seasonal=True, m=48, trace=True,
                          error_action='ignore', suppress_warnings=True, stepwise=True, 
                          d=0)  # Set d=0 because data is already differenced

print(sarima_order.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[48] intercept   : AIC=inf, Time=5681.80 sec
#  ARIMA(0,0,0)(0,0,0)[48] intercept   : AIC=4283614.927, Time=3.17 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 4
#       1 from pmdarima import auto_arima
#       3 # Determine the SARIMA order for the differenced data
# ----> 4 sarima_order = auto_arima(data['tsd_diff'].dropna(), seasonal=True, m=48, trace=True,
#       5                           error_action='ignore', suppress_warnings=True, stepwise=True,
#       6                           d=0)  # Set d=0 because data is already differenced
#       8 print(sarima_order.summary())
#
# File ~/anaconda3/lib/python3.11/site-packages/pmdarima/arima/auto.py:701, in auto_arima(y, X, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, maxiter, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
#     669     # init the stepwise model wrapper
#     670     search = solvers._StepwiseFitWrapper(
#     671         y,
#     672         X=X,
#    (...)
#     698         **sarimax_kwargs,
#     699     )
# --> 701 sorted_res = search.solve()
#     702 return _return_wrapper(sorted_res, return_valid_fits, start, trace)
#
# File ~/anaconda3/lib/python3.11/site-packages/pmdarima/arima/_auto_solvers.py:298, in _StepwiseFitWrapper.solve(self)
#     296 _p = 1 if max_p > 0 else 0
#     297 _P = 1 if (m > 1 and max_P > 0) else 0
# --> 298 if self._do_fit((_p, d, 0), (_P, D, 0, m)):
#     299     p = _p
#     300     P = _P
#
# File ~/anaconda3/lib/python3.11/site-packages/pmdarima/arima/_auto_solvers.py:235, in _StepwiseFitWrapper._do_fit(self, order, seasonal_order, constant)
#     230 if (order, seasonal_order, constant) not in self.results_dict:
#     231
#     232     # increment the number of fits
#     233     self.k += 1
# --> 235     fit, fit_time, new_ic = self._fit_arima(
#     236         order=order,
#     237         seasonal_order=seasonal_order,
#     238         with_intercept=constant)
#     240     # use the orders as a key to be hashed for
#     241     # the dictionary (pointing to fit)
#     242     self.results_dict[(order, seasonal_order, constant)] = fit
#
# File ~/anaconda3/lib/python3.11/site-packages/pmdarima/arima/_auto_solvers.py:508, in _fit_candidate_model(y, X, order, seasonal_order, start_params, trend, method, maxiter, fit_params, suppress_warnings, trace, error_action, out_of_sample_size, scoring, scoring_args, with_intercept, information_criterion, **kwargs)
#     500 fit = ARIMA(order=order, seasonal_order=seasonal_order,
#     501             start_params=start_params, trend=trend, method=method,
#     502             maxiter=maxiter, suppress_warnings=suppress_warnings,
#     503             out_of_sample_size=out_of_sample_size, scoring=scoring,
#     504             scoring_args=scoring_args,
#     505             with_intercept=with_intercept, **kwargs)
#     507 try:
# --> 508     fit.fit(y, X=X, **fit_params)
#     510 # for non-stationarity errors or singular matrices, return None
#     511 except (LinAlgError, ValueError) as v:
#
# File ~/anaconda3/lib/python3.11/site-packages/pmdarima/arima/arima.py:603, in ARIMA.fit(self, y, X, **fit_args)
#     600         X = safe_indexing(X, slice(0, n_exog - cv))
#     602 # Internal call
# --> 603 self._fit(y, X, **fit_args)
#     605 # now make a forecast if we're validating to compute the
#     606 # out-of-sample score
#     607 if cv_samples is not None:
#     608     # get the predictions (use self.predict, which calls forecast
#     609     # from statsmodels internally)
#
# File ~/anaconda3/lib/python3.11/site-packages/pmdarima/arima/arima.py:524, in ARIMA._fit(self, y, X, **fit_args)
#     522     with warnings.catch_warnings(record=False):
#     523         warnings.simplefilter('ignore')
# --> 524         fit, self.arima_res_ = _fit_wrapper()
#     525 else:
#     526     fit, self.arima_res_ = _fit_wrapper()
#
# File ~/anaconda3/lib/python3.11/site-packages/pmdarima/arima/arima.py:510, in ARIMA._fit.<locals>._fit_wrapper()
#     507 _maxiter = fit_args.pop("maxiter", _maxiter)
#     509 disp = fit_args.pop("disp", 0)
# --> 510 fitted = arima.fit(
#     511     start_params=start_params,
#     512     method=method,
#     513     maxiter=_maxiter,
#     514     disp=disp,
#     515     **fit_args,
#     516 )
#     518 return arima, fitted
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/mlemodel.py:704, in MLEModel.fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     702         flags['hessian_method'] = optim_hessian
#     703     fargs = (flags,)
# --> 704     mlefit = super(MLEModel, self).fit(start_params, method=method,
#     705                                        fargs=fargs,
#     706                                        maxiter=maxiter,
#     707                                        full_output=full_output,
#     708                                        disp=disp, callback=callback,
#     709                                        skip_hessian=True, **kwargs)
#     711 # Just return the fitted parameters if requested
#     712 if return_params:
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:566, in LikelihoodModel.fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     563     del kwargs["use_t"]
#     565 optimizer = Optimizer()
# --> 566 xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     567                                                fargs, kwargs,
#     568                                                hessian=hess,
#     569                                                method=method,
#     570                                                disp=disp,
#     571                                                maxiter=maxiter,
#     572                                                callback=callback,
#     573                                                retall=retall,
#     574                                                full_output=full_output)
#     575 # Restore cov_type, cov_kwds and use_t
#     576 optim_settings.update(kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/base/optimizer.py:242, in Optimizer._fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     239     fit_funcs.update(extra_fit_funcs)
#     241 func = fit_funcs[method]
# --> 242 xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     243                      disp=disp, maxiter=maxiter, callback=callback,
#     244                      retall=retall, full_output=full_output,
#     245                      hess=hessian)
#     247 optim_settings = {'optimizer': method, 'start_params': start_params,
#     248                   'maxiter': maxiter, 'full_output': full_output,
#     249                   'disp': disp, 'fargs': fargs, 'callback': callback,
#     250                   'retall': retall, "extra_fit_funcs": extra_fit_funcs}
#     251 optim_settings.update(kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/base/optimizer.py:659, in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     656 elif approx_grad:
#     657     func = f
# --> 659 retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     660                                  callback=callback, args=fargs,
#     661                                  bounds=bounds, disp=disp,
#     662                                  **extra_kwargs)
#     664 if full_output:
#     665     xopt, fopt, d = retvals
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/optimize/_lbfgsb_py.py:199, in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     187 callback = _wrap_callback(callback)
#     188 opts = {'disp': disp,
#     189         'iprint': iprint,
#     190         'maxcor': m,
#    (...)
#     196         'callback': callback,
#     197         'maxls': maxls}
# --> 199 res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     200                        **opts)
#     201 d = {'grad': res['jac'],
#     202      'task': res['message'],
#     203      'funcalls': res['nfev'],
#     204      'nit': res['nit'],
#     205      'warnflag': res['status']}
#     206 f = res['fun']
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/optimize/_lbfgsb_py.py:361, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     355 task_str = task.tobytes()
#     356 if task_str.startswith(b'FG'):
#     357     # The minimization routine wants f and g at the current x.
#     358     # Note that interruptions due to maxfun are postponed
#     359     # until the completion of the current minimization iteration.
#     360     # Overwrite f and g:
# --> 361     f, g = func_and_grad(x)
#     362 elif task_str.startswith(b'NEW_X'):
#     363     # new iteration
#     364     n_iterations += 1
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:286, in ScalarFunction.fun_and_grad(self, x)
#     284     self._update_x_impl(x)
#     285 self._update_fun()
# --> 286 self._update_grad()
#     287 return self.f, self.g
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:256, in ScalarFunction._update_grad(self)
#     254 def _update_grad(self):
#     255     if not self.g_updated:
# --> 256         self._update_grad_impl()
#     257         self.g_updated = True
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:173, in ScalarFunction.__init__.<locals>.update_grad()
#     171 self._update_fun()
#     172 self.ngev += 1
# --> 173 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     174                            **finite_diff_options)
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:505, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     502     use_one_sided = False
#     504 if sparsity is None:
# --> 505     return _dense_difference(fun_wrapped, x0, f0, h,
#     506                              use_one_sided, method)
#     507 else:
#     508     if not issparse(sparsity) and len(sparsity) == 2:
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:576, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     574     x = x0 + h_vecs[i]
#     575     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 576     df = fun(x) - f0
#     577 elif method == '3-point' and use_one_sided[i]:
#     578     x1 = x0 + h_vecs[i]
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:456, in approx_derivative.<locals>.fun_wrapped(x)
#     455 def fun_wrapped(x):
# --> 456     f = np.atleast_1d(fun(x, *args, **kwargs))
#     457     if f.ndim > 1:
#     458         raise RuntimeError("`fun` return value has "
#     459                            "more than 1 dimension.")
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:534, in LikelihoodModel.fit.<locals>.f(params, *args)
#     533 def f(params, *args):
# --> 534     return -self.loglike(params, *args) / nobs
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/mlemodel.py:939, in MLEModel.loglike(self, params, *args, **kwargs)
#     936 if complex_step:
#     937     kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
# --> 939 loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     941 # Koopman, Shephard, and Doornik recommend maximizing the average
#     942 # likelihood to avoid scale issues, but the averaging is done
#     943 # automatically in the base model `fit` method
#     944 return loglike
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/kalman_filter.py:1001, in KalmanFilter.loglike(self, **kwargs)
#     985 r"""
#     986 Calculate the loglikelihood associated with the statespace model.
#     987
#    (...)
#     997     The joint loglikelihood.
#     998 """
#     999 kwargs.setdefault('conserve_memory',
#    1000                   MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# -> 1001 kfilter = self._filter(**kwargs)
#    1002 loglikelihood_burn = kwargs.get('loglikelihood_burn',
#    1003                                 self.loglikelihood_burn)
#    1004 if not (kwargs['conserve_memory'] & MEMORY_NO_LIKELIHOOD):
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/kalman_filter.py:924, in KalmanFilter._filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     921 self._initialize_state(prefix=prefix, complex_step=complex_step)
#     923 # Run the filter
# --> 924 kfilter()
#     926 return kfilter
#
# KeyboardInterrupt:

# %% [markdown]
# **Note**: auto_arima parameters
#
# - **seasonal=True**: Indicates we want to consider the seasonal component.
# - **m=48**: This specifies the seasonal frequency of the time series (30 min intervals/day, in this case).
# - **trace=True**: This will show progress during the search.
# - **stepwise=True**: Accelerates the search process by considering a more restricted set of possible parameter combinations (based on the best parameters found in the previous step).
#
# Once you've run the above code, the summary will provide the order (p, d, q) and seasonal order (P, D, Q, S) that were found to be the best for your dataset.
